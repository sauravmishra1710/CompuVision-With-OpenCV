# %% [markdown]
# # Image Thresholding
#
#
#
#     Thresholding is a technique in OpenCV, which is the assignment of pixel values in relation to the threshold value.
#     Each pixel value is compared with the threshold value. If the pixel value is less than the threshold, it is set to 0,
#     else, it is set to a 255. Thresholding is the simplest method of segmenting image. From a grayscale image, thresholding
#     can be used to create binary images.
#
#     In Computer Vision, this technique of thresholding is done on grayscale images. So initially, the image has to be
#     converted in grayscale color space.
#
#     Image thresholding is a simple, yet effective, way of partitioning an image into a foreground and background.
#     This image analysis technique is a type of image segmentation that isolates objects by converting grayscale images
#     into binary images. Image thresholding is most effective in images with high levels of contrast.
#
#
# ### Types of Thresholding -
#
#     1. Simple Thresholding
#     2. Adaptive Thresholding
#     3. Otsu Thresholding
#
# ### Ref -
#
#  - https://opencv-python-tutroals.readthedocs.io/en/latest/py_tutorials/py_imgproc/py_thresholding/py_thresholding.html#thresholding
#
#  - https://in.mathworks.com/discovery/image-thresholding.html
#
#
# ### Saurav Mishra

# %% [markdown]
# ## Simple Thresholding
#
#     If pixel value is greater than a threshold value, it is assigned one value (may be white), else it is assigned another
#     value (may be black).
#
#     The algorithm for simple thresholding looks like -
#
#         If pixel_value(x, y) > thresh_value:
#            pixel_value(x, y) = 0
#         else:
#            pixel_value(x, y) = 255
#
#     where,
#     pixel_value(x, y) = Pixel Value at the location (x, y)
#     thresh_value = Threshold Value to be considered as boundary for convertion.
#
# **OpenCV Function - threshold(src, thresh, maxval, type[, dst]) -> retval, dst**
#
#     Applies a fixed-level threshold to each array element. The function applies fixed-level thresholding to a multiple-channel
#     array. The function is typicallyused to get a binary image out of a grayscale image ( #compare could be also
#     used for this purpose) or for removing a noise, that is, filtering out pixels with too small or too large values.
#     There are several types of thresholding supported by the function. They are determined by type parameter.
#
#     Also, the special values #THRESH_OTSU or #THRESH_TRIANGLE may be combined with one of the above values. In these cases,
#     the function determines the optimal threshold value using the Otsu's or Triangle algorithm and uses it instead of
#     the specified thresh.
#
#    **Currently, the Otsu's and Triangle methods are implemented only for 8-bit single-channel images.**
#
#    **Function Parameters**
#  - **src** input array (multiple-channel, 8-bit or 32-bit floating point).
#  - **dst** output array of the same size  and type and the same number of channels as src.
#  - **thresh** threshold value.
#  - **maxval** maximum value to use with the #THRESH_BINARY and #THRESH_BINARY_INV thresholding types.
#  - **type** thresholding type (see #ThresholdTypes).
#
#
#  **Return Value**
#  - **retval** the computed threshold value if Otsu's or Triangle methods used. If Ostu's method is not use the passed
#    **thresh** value is returned as is.
#  - **dst** the thresholded version of the image.
#
#
#   OpenCV provides different **styles of thresholding** and it is decided by the fourth parameter of the function. Different types are:
#
#  - cv2.THRESH_BINARY
#  - cv2.THRESH_BINARY_INV
#  - cv2.THRESH_TRUNC
#  - cv2.THRESH_TOZERO
#  - cv2.THRESH_TOZERO_INV

# %%
# Importing the required libraries and packages

import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# We will apply simple thresholding to the rainbow image -

# %%
img = cv2.imread('./Data/rainbow.jpg')

plt.imshow(img)

# %% [markdown]
# As thresholding works on binary images, lets first convert the image to birany mode -
#
# For more insights into the various read/write modes in openCV check - https://docs.opencv.org/4.2.0/d4/da8/group__imgcodecs.html#ga61d9b0126a3e57d9277ac48327799c80

# %%
img = cv2.imread('./DATA/rainbow.jpg', cv2.IMREAD_GRAYSCALE) # IMREAD_GRAYSCALE - 0

plt.imshow(img, cmap='gray')

# %% [markdown]
# #### Binary Threshold - cv2.THRESH_BINARY

# %%
ret,threshImgBinary = cv2.threshold(img, 127, 255, cv2.THRESH_BINARY)

plt.imshow(threshImgBinary, cmap='gray')

# %% [markdown]
# #### Binary Threshold - cv2.THRESH_BINARY_INV

# %%
ret,threshImgBinaryInv = cv2.threshold(img, 127, 255, cv2.THRESH_BINARY_INV)

plt.imshow(threshImgBinaryInv, cmap='gray')

# %% [markdown]
# #### Binary Threshold - cv2.THRESH_TRUNC

# %%
ret,threshImgTrunc = cv2.threshold(img, 127, 255, cv2.THRESH_TRUNC)

plt.imshow(threshImgTrunc, cmap='gray')

# %% [markdown]
# #### Binary Threshold - cv2.THRESH_TOZERO

# %%
ret,threshImgToZero = cv2.threshold(img, 127, 255, cv2.THRESH_TOZERO)

plt.imshow(threshImgToZero, cmap='gray')

# %% [markdown]
# #### Binary Threshold - cv2.THRESH_TOZERO_INV

# %%
ret,threshImgToZeroInv = cv2.threshold(img, 127, 255, cv2.THRESH_TOZERO_INV)

plt.imshow(threshImgToZeroInv, cmap='gray')

# %% [markdown]
# #### Lets apply the above thersholding styles to a more realistic image -

# %%
colored_image = cv2.imread('./Data/open_cv_python.jpg')

plt.imshow(colored_image)
plt.title('Original Colored Image')
plt.xticks([])
plt.yticks([])

plt.show()

# %%
img = cv2.imread('./Data/open_cv_python.jpg',cv2.IMREAD_GRAYSCALE)

ret,thresh_binary = cv2.threshold(img,127,255,cv2.THRESH_BINARY)
ret,thresh_binary_inv = cv2.threshold(img,127,255,cv2.THRESH_BINARY_INV)
ret,thresh_trunc = cv2.threshold(img,127,255,cv2.THRESH_TRUNC)
ret,thresh_tozero = cv2.threshold(img,127,255,cv2.THRESH_TOZERO)
ret,thresh_tozero_inv = cv2.threshold(img,127,255,cv2.THRESH_TOZERO_INV)

titles = ['Original Grey Image','THRESH_BINARY','THRESH_BINARY_INV','THRESH_TRUNC','THRESH_TOZERO','THRESH_TOZERO_INV']
images = [img, thresh_binary, thresh_binary_inv, thresh_trunc, thresh_tozero, thresh_tozero_inv]

plt.figure(figsize=(20,10))

for i in range(6):
    plt.subplot(2, 3, i+1)
    plt.imshow(images[i],'gray')
    plt.title(titles[i])
    plt.xticks([])
    plt.yticks([])

plt.show()

# %% [markdown]
# ## Adaptive Thresholding
#
#     In simple thresholding, we used a global threshold value. But it may not be good in all the conditions where image
#     has different lighting conditions in different areas. In that case, we go for adaptive thresholding. In this, the
#     algorithm calculate the threshold for a small regions of the image. So we get different thresholds for different
#     regions of the same image and it gives us better results for images with varying illumination.
#
#   **Adaptive Method - It decides how thresholding value is calculated.**
#  - cv2.ADAPTIVE_THRESH_MEAN_C : threshold value is the mean of neighbourhood area.
#  - cv2.ADAPTIVE_THRESH_GAUSSIAN_C : threshold value is the weighted sum of neighbourhood values where weights are a
#      gaussian window.
#
#   OpenCV provides the method **adaptiveThreshold(src, maxValue, adaptiveMethod, thresholdType, blockSize, C[, dst]) -> dst**
#      Applies an adaptive threshold to an array.
#
# **Function Parameters**
#  - **src** Source 8-bit single-channel image.
#  - **dst** Destination image of the same size and the same type as src.
#  - **maxValue** Non-zero value assigned to the pixels for which the condition is satisfied
#  - **adaptiveMethod** Adaptive thresholding algorithm to use, see #AdaptiveThresholdTypes.
#      The #BORDER_REPLICATE |   #BORDER_ISOLATED is used to process boundaries.
#  - **thresholdType** Thresholding type that must be either #THRESH_BINARY or #THRESH_BINARY_INV,
#  - **blockSize** Size of a pixel neighborhood that is used to calculate a threshold value for the pixel: 3, 5, 7, and so on.
#  - **C** Constant subtracted from the mean or weighted mean (see the details below). Normally, it is positive but may be zero or negative as well.
#
#
#   ### 1.
#
#  **Now lets see the two adaptive thresholding methods on some images -**

# %%
crossword = cv2.imread('./Data/crossword.jpg', cv2.IMREAD_GRAYSCALE)

crossword_THRESH_MEAN = cv2.adaptiveThreshold(crossword,255,cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY,115,1)
crossword_THRESH_GAUSSIAN = cv2.adaptiveThreshold(crossword,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY,115,1)

titles = ['Original Image', 'Adaptive Mean Thresholding', 'Adaptive Gaussian Thresholding']
images = [crossword, crossword_THRESH_MEAN, crossword_THRESH_GAUSSIAN]

plt.figure(figsize=(20,10))

for i in range(3):
    plt.subplot(1,3,i+1),plt.imshow(images[i], 'gray')
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])

plt.show()

# %% [markdown]
# ***Playing around with the different values the last 2 parameters blockSize & the constant C can take, will give different results.***
#
# ### 2.
#
# Now lets see the thresholding effects on a different image with a different lighting condition -

# %%
news_original_img = cv2.imread('./Data/news.jpg')
news_original_img = cv2.cvtColor(news_original_img, cv2.COLOR_BGR2RGB) # difference in the color channel sequence

plt.imshow(news_original_img, cmap='gray')
plt.title('Original Colored Image')
plt.xticks([])
plt.yticks([])

plt.show()

# %%
news_gray_img = cv2.imread('./Data/news.jpg', cv2.IMREAD_GRAYSCALE)

ret,news_THRESH_BINARY = cv2.threshold(news_gray_img,12,255,cv2.THRESH_BINARY)
news_THRESH_MEAN = cv2.adaptiveThreshold(news_gray_img,255,cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY,115,2)
news_THRESH_GAUSSIAN = cv2.adaptiveThreshold(news_gray_img,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY,45,2)

titles = ['Original Gray Image', 'Global Thresholding (v=12)', 'Adaptive Mean Thresholding', 'Adaptive Gaussian Thresholding']
images = [news_gray_img, news_THRESH_BINARY, news_THRESH_MEAN, news_THRESH_GAUSSIAN]

plt.figure(figsize=(20,10))

for i in range(4):
    plt.subplot(2,2,i+1)
    plt.imshow(images[i],'gray')
    plt.title(titles[i])
    plt.xticks([])
    plt.yticks([])

plt.show()

# %% [markdown]
# **As we see in the figure above that out of the 3 thresholding styles, the Adapdive Gaussian thhesholding style gives us a better and readable image. However, this might not always be the case. Other styles could as well give better results depending upon the image lighting and color dustribution.**
#
# ### 3.
# #### Now lets see the same in a colored image with various objects -

# %%
sea_colored_img = cv2.imread('./Data/sea.png')
sea_colored_img = cv2.cvtColor(sea_colored_img, cv2.COLOR_BGR2RGB) # difference in the color channel sequence

plt.imshow(sea_colored_img, cmap='gray')
plt.title('Original Colored Image')
plt.xticks([])
plt.yticks([])

plt.show()

# %%
sea_gray = cv2.imread('./Data/sea.png', cv2.IMREAD_GRAYSCALE)

ret,sea_THRESH_BINARY = cv2.threshold(sea_gray,127,255,cv2.THRESH_BINARY)
sea_ADAPTIVE_THRESH_MEAN = cv2.adaptiveThreshold(sea_gray,255,cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY,115,1)
sea_ADAPTIVE_THRESH_GAUSSIAN = cv2.adaptiveThreshold(sea_gray,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY,115,1)

titles = ['Original Image', 'Global Thresholding (v=127)', 'Adaptive Mean Thresholding', 'Adaptive Gaussian Thresholding']
images = [sea_gray, sea_THRESH_BINARY, sea_ADAPTIVE_THRESH_MEAN, sea_ADAPTIVE_THRESH_GAUSSIAN]

plt.figure(figsize=(20,10))

for i in range(4):
    plt.subplot(2,2,i+1),plt.imshow(images[i],'gray')
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])

plt.show()

# %% [markdown]
# **Again as we see the the sub plots above the adaptive gaussian thresholding style gives a comparitively better picture than the other styles.**

# %% [markdown]
# ## Otsu’s Binarization
#
#     We saw previously that the simple thresholding method returns 2 values - the retVal and the thresholded image
#     The use of retVal come in this style of thresholding.
#
#     In global thresholding, we used an arbitrary value for threshold value. So, we have to trial and error on different
#     values to decide if the selected is good or not?
#
#     But consider a bimodal image (bimodal image is an image whose histogram has two peaks). For such image, we
#     can approximately take a value in the middle of those peaks as threshold value. That is what Otsu binarization does.
#     So in simple words, it automatically calculates a threshold value from image histogram for a bimodal image.
#     (For images which are not bimodal, binarization won’t be accurate.)
#
#     To perform Otsu’s Binarization we use the same cv2.threshold() function, but pass an extra flag, cv2.THRESH_OTSU.
#     For threshold (thresh) value, simply pass zero. Then the algorithm finds the optimal threshold value and returns
#     that as the second output, retVal. If Otsu thresholding is not used, retVal is same as the threshold value you used.
#
#    **For the method explataion and defination check the section on Simple Thresholding. It remains the same.**
#
# ### How Otsu’s Binarization Works?
#
#
#
#     As this method involves bimodal images, Otsu’s algorithm tries to find a threshold value (t) which minimizes the
#     weighted within-class variance given by the relation :
#
# ![image.png](attachment:image.png)
#
# **Ref -** https://opencv-python-tutroals.readthedocs.io/en/latest/py_tutorials/py_imgproc/py_thresholding/py_thresholding.html#thresholding
#
#    https://medium.com/@hbyacademic/otsu-thresholding-4337710dc519 (a good read on how Otsu’s Binarization Works)
#
#     Otsu’s method is an adaptive thresholding way for binarization in image processing. By going through all possible
#     threshold values (from 0 to 255), it can find the optimal threshold value of input image.
#
#     It works directly at the histogram level. The following steps are followed -
#
# ##### 1. Create histogram for the Input Image -
#
#    **We assume that the input image is an grayscale image. As for the RGB input image, it should be converted into
#    grayscale image first.**
#
#     In Otsu thresholding, statistical data of an image is used through the image pixel distribution using the “Histogram”.
#     It looks at the number of every pixel value in the image.
#
#
# ##### 2. Within-class Variance -
#
#     Using the histogram if we choose the threshold value T=2, then the image is separated into two classes, where Class 1
#     (pixel value<=2) and Class 2 (pixel value>2). We can say that these two classes represent background and foreground of
#     the input image respectively. (Class 2 can be the background if foreground is darker than background)
#
#     In terms of the within-class variance (Vw, for short), the lower the value of Vw is, the less dispersed the data in each
#     class is (background and foreground). As the result, to get the optimal threshold value is to find the minimal value of Vw.
#
#     It actually finds a value of threshold which lies in between two peaks such that variances to both classes are minimum.
#
# #### Now lets see some examples on Otsu’s Binarization -

# %%
noisy_lena_img = cv2.imread('./Data/lena_noisy2.png', cv2.IMREAD_GRAYSCALE)

# global thresholding
retVal1, simple_thresh = cv2.threshold(noisy_lena_img, 127, 255, cv2.THRESH_BINARY)

# Otsu's thresholding
retVal2, ostus_thresh = cv2.threshold(noisy_lena_img, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

# Otsu's thresholding after Gaussian filtering
blur_noisy_lena_img = cv2.GaussianBlur(noisy_lena_img, (5,5), 0)
retVal3, ostus_thresh_after_blur = cv2.threshold(blur_noisy_lena_img, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

print("Simple Threshold return value on original image - ", retVal1)
print("Ostu's return value on original image - ", retVal2)
print("Ostu's return value on blurred image - ", retVal3)

# plot all the images and their histograms
images = [noisy_lena_img, 0, simple_thresh,
          noisy_lena_img, 0, ostus_thresh,
          blur_noisy_lena_img, 0, ostus_thresh_after_blur]

titles = ['Original Noisy Image','Histogram','Global Thresholding (v=127)',
          'Original Noisy Image','Histogram',"Otsu's Thresholding",
          'Gaussian filtered Image','Histogram',"Otsu's Thresholding"]

plt.figure(figsize=(20,10))

for i in range(3):
    plt.subplot(3,3,i*3+1),plt.imshow(images[i*3],'gray')
    plt.title(titles[i*3]), plt.xticks([]), plt.yticks([])
    
    plt.subplot(3,3,i*3+2),plt.hist(images[i*3].ravel(),256)
    plt.title(titles[i*3+1]), plt.xticks([]), plt.yticks([])
    
    plt.subplot(3,3,i*3+3),plt.imshow(images[i*3+2],'gray')
    plt.title(titles[i*3+2]), plt.xticks([]), plt.yticks([])

plt.show()
# Out:
# Simple Threshold return value on original image -  127.0
# Ostu's return value on original image -  118.0
# Ostu's return value on blurred image -  118.0

# %% [markdown]
# #### Now lets observe the Ostu's Binarization on the sea image we saw above -

# %%
sea_gray = cv2.imread('./Data/sea.png', cv2.IMREAD_GRAYSCALE)

ret,sea_THRESH_BINARY = cv2.threshold(sea_gray,127,255,cv2.THRESH_BINARY)
sea_ADAPTIVE_THRESH_MEAN = cv2.adaptiveThreshold(sea_gray,255,cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY,115,1)
sea_ADAPTIVE_THRESH_GAUSSIAN = cv2.adaptiveThreshold(sea_gray,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY,115,1)
retVal2, sea_OSTUS_BINARIZATION = cv2.threshold(sea_gray, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

titles = ['Global Thresholding (v=127)', 'Adaptive Mean Thresholding', 'Adaptive Gaussian Thresholding', 'Ostus Binarization']
images = [sea_THRESH_BINARY, sea_ADAPTIVE_THRESH_MEAN, sea_ADAPTIVE_THRESH_GAUSSIAN, sea_OSTUS_BINARIZATION]

plt.figure(figsize=(20,10))

for i in range(4):
    plt.subplot(2,2,i+1),plt.imshow(images[i],'gray')
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])

plt.show()

# %% [markdown]
# **Now lets see the thresholding on a real image of the nature involving the sea and other objects**

# %%
nature_img = cv2.imread('./Data/nature.JPG', cv2.IMREAD_GRAYSCALE)

# global thresholding
retVal1, simple_thresh = cv2.threshold(nature_img, 160, 255, cv2.THRESH_BINARY)

# Otsu's thresholding
retVal2, ostus_thresh = cv2.threshold(nature_img, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

# Otsu's thresholding after Gaussian filtering
blur_nature_img = cv2.GaussianBlur(nature_img, (5,5), 0)
retVal3, ostus_thresh_after_blur = cv2.threshold(blur_nature_img, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

print("Simple Threshold return value on original image - ", retVal1)
print("Ostu's return value on original image - ", retVal2)
print("Ostu's return value on blurred image - ", retVal3)

# plot all the images and their histograms
images = [nature_img, 0, simple_thresh,
          nature_img, 0, ostus_thresh,
          blur_nature_img, 0, ostus_thresh_after_blur]

titles = ['Original Image','Histogram','Global Thresholding (v=160)',
          'Original Image','Histogram',"Otsu's Thresholding",
          'Gaussian filtered Image','Histogram',"Otsu's Thresholding"]

plt.figure(figsize=(20,10))

for i in range(3):
    plt.subplot(3,3,i*3+1),plt.imshow(images[i*3],'gray')
    plt.title(titles[i*3]), plt.xticks([]), plt.yticks([])
    
    plt.subplot(3,3,i*3+2),plt.hist(images[i*3].ravel(),256)
    plt.title(titles[i*3+1]), plt.xticks([]), plt.yticks([])
    
    plt.subplot(3,3,i*3+3),plt.imshow(images[i*3+2],'gray')
    plt.title(titles[i*3+2]), plt.xticks([]), plt.yticks([])

plt.show()
# Out:
# Simple Threshold return value on original image -  160.0
# Ostu's return value on original image -  150.0
# Ostu's return value on blurred image -  151.0

# %% [markdown]
# ***So as we see different thresholding schemes perform differently on the images. The one which best works would depend on the kind of image we have at our disposal.***
